# %% [markdown]
# ## Load Previously Saved Model Data for Flask Visualisation

# %%
import lumispy as lum
import hyperspy.api as hs
hs.preferences.General.plot_backend = "mpl"
import hyperspy.api as hs
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2

# %%
folderpath = r"C:\Users\cobia\OneDrive - University of Cambridge\CL\COBI20250321\HYP-SI-FAT-END-OUTSIDE-05-AFM-REDO"

# %%
cl_sem = hs.load(os.path.join(folderpath, 'HYPCard_corrected.hspy'))
m_centre = hs.load(os.path.join(folderpath, 'HYPCard_corrected_m_centre.hspy'))
m_intensity = hs.load(os.path.join(folderpath, 'HYPCard_corrected_m_intensity.hspy'))
m_fwhm = m_intensity = hs.load(os.path.join(folderpath, 'HYPCard_corrected_m_fwhm.hspy'))

# %%
im = cl_sem.T


# Uncomment the following lines to visualize the CL image and ROI before image extraction
im.plot()
roi1 = hs.roi.SpanROI(left=350, right=380) #sets a digitalbandfilter
im_roi1 = roi1.interactive(im, color="red")
im_roi1_mean = hs.interactive(im_roi1.mean,
                        event=roi1.events.changed,
                        recompute_out_event=None)

cl_img = im_roi1_mean.data

# %%
import pickle

# Getting back the objects:
with open('./lumispy-demos/objs.pkl', 'rb') as f:
    MI_sub, m_centre2_data, m_intensity_data = pickle.load(f)

# %%
plt.imshow(cl_img)

# %%
m_ = m_centre.data
# Out:
# numpy.ndarray

# %%
MI_sub.shape
# Out:
# (256, 256)

# %%
m_intensity_data.shape
# Out:
# (256, 256)

# %%
plt.imshow(m_intensity.data)

# %%
plt.imshow(m_intensity_data)

# %%
MI_sub == m_intensity_data
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])
